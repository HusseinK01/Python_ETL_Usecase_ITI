# %%
import pandas as pd
import os

# %%
# Load customers.csv and stores.csv
customers_df = pd.read_csv('../Staging_1/Customers/customers.csv')
stores_df = pd.read_csv('../Staging_1/Stores/stores.csv')

# %%
# Get a set of unique cities from the stores DataFrame
store_cities = set(stores_df['city'])

# %%
# Add a new column 'local' to customers_df and set default value to False
customers_df['local'] = False

# Update 'local' column to True for customers in cities where there's a store
customers_df.loc[customers_df['city'].isin(store_cities), 'local'] = True

# Now customers_df contains the new column 'local'
customers_df
# Out:
#      customer_id  first_name  last_name           phone  \
# 0              5  Charolette       Rice  (916) 381-6003
# 1              7     Latasha       Hays  (716) 986-3359
# 2             12       Robby      Sykes  (516) 583-7761
# 3             16      Emmitt    Sanchez  (212) 945-8823
# 4             26        Theo      Reese  (562) 215-2907
# ..           ...         ...        ...             ...
# 173         1418       Penni       Best  (657) 611-2991
# 174         1423      Dollie  Cervantes  (682) 362-7457
# 175         1426       Londa      Gould  (361) 206-5550
# 176         1430       Tayna       Wade  (661) 858-1224
# 177         1438         Lee       Dunn  (408) 807-6157
#
#                           email                   street            city  \
# 0       charolette.rice@msn.com           107 River Dr.       Sacramento
# 1      latasha.hays@hotmail.com  7014 Manor Station Rd.          Buffalo
# 2       robby.sykes@hotmail.com   486 Rock Maple Street        Hempstead
# 3    emmitt.sanchez@hotmail.com    461 Squaw Creek Road         New York
# 4          theo.reese@gmail.com  8755 W. Wild Horse St.       Long Beach
# ..                          ...                      ...             ...
# 173          penni.best@msn.com        875 Second Drive          Anaheim
# 174    dollie.cervantes@aol.com    8828 Applegate Drive       Fort Worth
# 175         londa.gould@aol.com         9169 Beech Lane   Corpus Christi
# 176      tayna.wade@hotmail.com      65 Smith Store Dr.      Bakersfield
# 177            lee.dunn@aol.com         8626 Grand Ave.         San Jose
#
#     state  zip_code source             timestamp_saved  local
# 0      CA     95820     DL  2024-04-28 21:09:05.648232  False
# 1      NY     14215     DL  2024-04-28 21:09:05.648232  False
# 2      NY     11550     DL  2024-04-28 21:09:05.648232  False
# 3      NY     10002     DL  2024-04-28 21:09:05.648232  False
# 4      NY     11561     DL  2024-04-28 21:09:05.648232  False
# ..    ...       ...    ...                         ...    ...
# 173    CA     92806     DL  2024-04-28 21:09:05.648232  False
# 174    TX     76110     DL  2024-04-28 21:09:05.648232  False
# 175    TX     78418     DL  2024-04-28 21:09:05.648232  False
# 176    CA     93306     DL  2024-04-28 21:09:05.648232  False
# 177    CA     95127     DL  2024-04-28 21:09:05.648232  False
#
# [178 rows x 12 columns]

# %%
file_path = '../Staging_2/Customers/customers.csv'

os.makedirs(os.path.dirname(file_path), exist_ok=True)
customers_df.to_csv(file_path, index = False)
